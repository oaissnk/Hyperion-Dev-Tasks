# %% [markdown]
# # Machine Learning
# ## Compulsory task

# %% [markdown]
# 1. For each of the following examples describe at least one possible input and
# output. Justify your answers:
# * 1.1 A self-driving car
# * 1.2 Netflix recommendation system
# * 1.3 Signature recognition
# * 1.4 Medical diagnosis

# %% [markdown]
# 1. Answer here
#
# |      | Input(s)    | Output     |
# | ---- | ----------- | ---------  |
# | 1.1  |    Camera   |Breaking    |
# | 1.2  | Demographic |Movie Recommendations|
# | 1.3  | Images      |Verification|
# | 1.4  | X-Ray       |Body abnormalities|
#
# # Camera will help car know its environment by taking pictures of surroundings, break would be an output if near a recognised object
# # Demographic would be used to recommend movies based on demographics of the user
# # Images would be used to verify if the person is who he claims to be based on patterns of the signature like stroke length etc.
# # X-Ray would be used to detect body abnormalities as scans would give us the data for normal bodies and if something did not match we could assess it as abnormal.

# %% [markdown]
# 2. For each of the following case studies, determine whether it is appropriate to utilise regression or classification machine learning algorithms. Justify your answers:
# * 2.1 Classifying emails as promotion or social based on their content and metadata.
# * 2.2 Forecasting the stock price of a company based on historical data and market trends.
# * 2.3 Sorting images of animals into different species based on their visual features.
# * 2.4 Predicting the likelihood of a patient having a particular disease based on medical history and diagnostic test results.

# %% [markdown]
# 2. Answer here
# * 2.1 Classification, as we need to classify the data into 2 classes.
# * 2.2 Regression, as we need to predict the values of the data based on previous trends
# * 2.3 Classification, to categorise the animals based on their features and looks
# * 2.4 Classification, to separate patients who do and do not have a disease.

# %% [markdown]
# 3. For each of the following real-world problems, determine whether it is appropriate to utilise a supervised or unsupervised machine learning algorithm. Justify your answers:
# * 3.1 Detecting anomalies in a manufacturing process using sensor data without prior knowledge of specific anomaly patterns.
# * 3.2 Predicting customer lifetime value based on historical transaction data and customer demographics.
# * 3.3 Segmenting customer demographics based on their purchase history, browsing behaviour, and preferences.
# * 3.4 Analysing social media posts to categorise them into different themes.

# %% [markdown]
# 3. Answer here
# * 3.1 Unsupervised learning, detecting anomalies doesn't require labelled examples. Would be better for detection with no prior knowledge
# * 3.2 Supervised, good for historical data with previous values to predict future values
# * 3.3 Unsupervised, since there are no predefined groups or categories, its good to use unsupervised so the data can be dealt with and maybe patters come up which wouldn't show if we used pre defined supervised learning
# * 3.4 Unsupervised, similar reasons to the previous answer

# %% [markdown]
# 4.
# For each of the following real-world problems, determine whether it is appropriate to utilise semi-supervised machine learning algorithms. Justify your answers:
# * 4.1 Predicting fraudulent financial transactions using a dataset where most transactions are labelled as fraudulent or legitimate.
# * 4.2 Analysing customer satisfaction surveys where only a small portion of the data is labelled with satisfaction ratings.
# * 4.3 Identifying spam emails in a dataset where the majority of emails are labelled.
# * 4.4 Predicting the probability of default for credit card applicants based on their complete financial and credit-related information.

# %% [markdown]
# 4. Answer here
# * 4.1 We're mostly dealing with knowing whether transactions are real or fraudulent. But sometimes, there might be transactions that we're not sure about or ones that are marked incorrectly therefore semi-supervised could be used
# * 4.2 Semi supervised would be ideal as only a small portion of data is labelled.
# * 4.3 If majority is already labelled probably best for supervised learning, a case could be made for semi though. Depends on the exact proportions
# * 4.4 Supervised for the same reason given in previous answer.
